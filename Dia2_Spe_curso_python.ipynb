# %% [markdown]
# <a href="https://colab.research.google.com/github/JoseAnArt/Python-for-Oil-Gas/blob/main/Dia2_Spe_curso_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Bucles**
# * Los bucles son usados cuando necesitamos repetir alguna linea de codigo.
# * Estos pueden hacer que nuestro trabajo sea mas facil.

# %% [markdown]
# **Bucle while**
# *  es usado cuando: Queremos que se muestre o se haga cualquier cosa hasta una dada condicion sea TRUE.

# %%
#por ejemplo
# queremos que se muetre un mensaje de salida 100 veces.
print("Hola mundo")
# Out:
# Hola mundo

# %%
#Debemos declarar una variable para que lleve la cuenta
c = 1
c2=c+1
while c <= 100:
  print("Hola que tal")
  c+=1
  print(c)

# %%
#suma de numeros

i=0
total= 0

while i <= 10:
  total = total + i
  print(total)
  i=1 + i
# 0
# 0+1= 1
# 1+2= 3
# 3+3= 6
#6+4= 10

# %% [markdown]
# if & else en un bucle while

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# donde:
#
# SG= Gravedad especifica del fluido @60 °F

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
GE=[0.85,0.86,0.87,0.88,0.89,0.9,0.95,0.96,0.97,0.98,0.99,1]
i=0

while i < len(GE):
  SG= GE[i]
  API= round((141.5/SG -131.5),1)
  if API <=10:
    print(f"El grado API con una GE de {SG} es {API} y se clasifica como un crudo Extra Pesado ")
  elif API > 10 and API <= 22.3:
    print(f"El grado API con una GE de {SG} es {API} y se clasifica como un crudo Pesado ")
  elif API > 22.3 and API <= 31.1:
    print(f"El grado API con una GE de {SG} es {API} y se clasifica como un crudo Mediano ")
  elif API > 31.1  and API <= 39:
    print(f"El grado API con una GE de {SG} es {API} y se clasifica como un crudo Ligero ")
  elif API > 39:
    print(f"El grado API con una GE de {SG} es {API} y se clasifica como un crudo Ligero ")
  i+=1

# %% [markdown]
# **Bucle for**
#
# Un ciclo *for* es una estructura que se utiliza para ejecutar un bloque de código un número determinado de veces.

# %% [markdown]
# Funcion range()

# %%
# mostrar del 0 al 5 en un bucle usando la funcion range()
for i in range(0,6):      #i=1,i=2,i=3,i=4,i=5
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
#otra forma de usar el range
for i in range(6):
   print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
#suma de numeros
# con while
i=0
total= 0
while i <= 10:
  total = total + i
  print(total)
  i=1 + i

# %%
#con for
total= 0
for i in range(11):
  total= i+total
  print(total)

# %%
tot=0
num= 2240
num2 = str(num)
for i in range(len(num2)):
  a= int(num2[i])
  b= tot
  tot= a+b
  print("{} + {} = {} ".format(a,b,tot))
print(tot)

# %% [markdown]
# **Funciones**
#
# * Las funciones son bloques de código que se pueden reutilizar simplemente llamando a la función.

# %%
# nos ayuda a reutilizar codigo sin estar escribiendolo una y otra vez
#ya existen funciones creadas por python: len(), print(),float, etc
len("reservorio")
# Out:
# 10

# %%
print("Reservorio")
# Out:
# Reservorio

# %%
float(20.25)
# Out:
# 20.25

# %%
list= [2,0,4,6,8,100,4,25]

for i in range(len(list)):
  if list[i] == min(list):
    print(f"la posicion del val min es : {i}")
  elif  list[i] == max(list):
    print(f"la posicion del val max es : {i}")
# Out:
# la posicion del val min es : 1
# la posicion del val max es : 5

# %%
#ahora vamos a crear una simple funcion
def mi_funcion():
  return "Esta es nuestra primera funcion"

# %%
#ahora poder llamarla usaremos de esta forma
mi_funcion()
# Out:
# 'Esta es nuestra primera funcion'

# %%
#ahora tambien podemos añadir ciertos parametros a nuestra funcion
def multiplicacion(a,b):
  return a/b

# %%
a,b=2,5
multiplicacion(8,5)
# Out:
# 1.6

# %%
def suma(a,b,c):
  return a+b+c

# %%
suma("yo","estudio","petróleos")
# Out:
# 'yoestudiopetróleos'

# %% [markdown]
# **Práctica**

# %%
#Pregunta al usuario un valor de saturacion de agua entre 0 y 1
#mostrar la saturacion de hidrocarburo usando una funcion llamada "hc_sat"
#la salida debe mostrar en este formato.- "La saturacion de hidrocarburo es "

# %%
sat_hc= float(input("Ingres un valor de saturacion de agua: "))
print(f"La saturacion de hidrocarburo es: {1-sat_hc} ")
# Out:
# Ingres un valor de saturacion de agua: 0.68
# La saturacion de hidrocarburo es: 0.31999999999999995

# %%
def hc_sat():
  sat_hc= float(input("Ingres un valor de saturacion de agua: "))
  return (f"La saturacion de hidrocarburo es: {1-sat_hc} ")

# %%
hc_sat()
# Out:
# Ingres un valor de saturacion de agua: 0.75
# 'La saturacion de hidrocarburo es: 0.25 '

# %%
#Vamos a crear una funcion que revise si el valor de porosidad es el correcto o no.
#tendremos que usar el if & else porque

# %% [markdown]
# Un pozo produce 1000 bbl/día de petróleo de 40 grados API y viscosidad de 1.2 cp, a través de una tubería con un ID: 2 7/8 pulgadas.
# Determine que numero de reynolds y cual es el tipo de regimen del fluido.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#crear una funcion con los paramentros necesarios para determinar el numero de reynolds y el regimen de flujo
#usar los condicionales if & else para determinar el regimen de flujo
# los condicionales deben ir dentro de la funcion.

# %%
import math
def Nre_function(Q,API,u,d):
  SG= 141.5/(131.5+API)
  p= 62.4*SG
  D=d/12
  v=4*5.615*Q/(math.pi*D**2*86400)
  Nre= 1.48*Q*p/(d*u)
  if Nre <2100:
    return f"El Número de reynolds es {round(Nre,2)} lo que indica flujo laminar"
  else:
    return f"El Número de reynolds es {round(Nre,2)} lo que indica flujo Turbulento"

# %%
Nre_function(1000,40,20.2,2.259)

# %%
k1,k2,k3= input("enter 3 permeabilitis :").split(",")
print(k1,k2)
# Out:
# enter 3 permeabilitis :1,2,3
# 1 2
